# %%
import os

import seaborn as sns
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler

import tensorflow as tf

# %%
lstm_pred_sj = pd.read_csv("../deng_predictions/lstm_sj_pred.csv")
extra_pred_sj = pd.read_csv("../deng_predictions/sj_extra_preds.csv")  # Rename file

# %% [markdown]
# ### Distinct Predictors

# %%
plt.plot(lstm_pred_sj, label = "lstm")
plt.plot(extra_pred_sj, label = "extraTrees")
plt.legend()
plt.show()

# %% [markdown]
# ## Ensembling SJ

# %%
# Decide about how you want to weight these
# Depending on how they do on the validation set.

# Do they get peaks better or worse?
# Certain months ?  etc.

# %%
# Simple mean ensemble
sj_ensemble = (lstm_pred_sj + extra_pred_sj) / 2

# %%
plt.plot(sj_ensemble)
plt.show()

# %% [markdown]
# ##  Distinct Predictors IQ

# %% [markdown]
# ## Ensembling IQ

# %% [markdown]
# ## Combining outputs
